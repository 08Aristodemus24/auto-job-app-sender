# %% [markdown]
# # This notebook attempts to train a classifier that predicts a persons gender based on name

# %%
import tensorflow as tf

# %% [markdown]
# # get the following features under each category
# ## lexical features
# * n-tokens
# * char n-grams
# * word n-grams
# * lemma n-grams
#
# ## morphological features
# * coare grained part-of-speech (POS) n-grams
# * fine grained part-of-speech (POS) n-grams
# * coare grained part of speech distribution
